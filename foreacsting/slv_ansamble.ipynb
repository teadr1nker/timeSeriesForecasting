# %%
import yfinance as yf
from best_test import testBest
import matplotlib.pyplot as plt
from RNN_PSAR import testRNNPSAR
# Out:
# 2024-06-02 23:49:48.436511: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-02 23:49:48.436713: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-02 23:49:48.438982: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-02 23:49:48.466365: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-02 23:49:48.968250: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Seed: 30245
# Seed: 30245

# %%
ticker = 'slv'
data = yf.download(ticker, '2012-01-01', '2022-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
plt.plot(data['Adj Close'])

# %%
res = testBest(data['Adj Close'].values, 20)
# Out:
# 2013
# (70, 1)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:32: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# (1943, 20, 3)
# Epoch 1/4
# 972/972 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0073
# Epoch 2/4
# 972/972 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0017
# Epoch 3/4
# 972/972 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0010
# Epoch 4/4
# 972/972 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 9.4498e-04
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 20, 50)         │         2,700 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 20, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, 20, 50)         │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_2 (SimpleRNN)        │ (None, 20, 25)         │         1,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_3 (SimpleRNN)        │ (None, 50)             │         3,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,004 (105.49 KB)
#  Trainable params: 13,501 (52.74 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 13,503 (52.75 KB)
# (70, 1)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# (1943, 20, 3)
# Epoch 1/6
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.0000e+00 - loss: 0.0075
# Epoch 2/6
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.0000e+00 - loss: 0.0010
# Epoch 3/6
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.0000e+00 - loss: 8.1061e-04
# Epoch 4/6
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.0000e+00 - loss: 5.8877e-04
# Epoch 5/6
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.0000e+00 - loss: 4.3329e-04
# Epoch 6/6
# 1943/1943 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.0000e+00 - loss: 3.8470e-04
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 20, 50)         │        10,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 96,905 (378.54 KB)
#  Trainable params: 32,301 (126.18 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 64,604 (252.36 KB)
# (70, 1)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:32: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# (1943, 20, 3)
# Epoch 1/4
# 972/972 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0102
# Epoch 2/4
# 972/972 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - loss: 0.0016
# Epoch 3/4
# 972/972 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - loss: 0.0011
# Epoch 4/4
# 972/972 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - loss: 7.8447e-04
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 20, 50)         │         8,250 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 20, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 20, 50)         │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 20, 50)         │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 50)             │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 108,404 (423.46 KB)
#  Trainable params: 54,201 (211.72 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 54,203 (211.73 KB)
# (70, 1)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:32: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# (1943, 20, 2)
# Epoch 1/4
# 972/972 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0121
# Epoch 2/4
# 972/972 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - loss: 0.0011
# Epoch 3/4
# 972/972 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - loss: 9.9887e-04
# Epoch 4/4
# 972/972 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - loss: 9.2257e-04
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_4 (GRU)                     │ (None, 20, 50)         │         8,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 20, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_5 (GRU)                     │ (None, 20, 50)         │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_6 (GRU)                     │ (None, 20, 50)         │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_7 (GRU)                     │ (None, 50)             │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 108,104 (422.29 KB)
#  Trainable params: 54,051 (211.14 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 54,053 (211.15 KB)

# %%
train ,forest, rnn, lstm, gru, gru1 = res

# %%
gruPSAR = testRNNPSAR(data[['Adj Close', 'Low', 'High']])
# Out:
# (20, 3)
# (1993, 20, 4) train
# (1993, 3) train fr
# Epoch 1/4
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:32: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# 997/997 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - loss: 0.0087
# Epoch 2/4
# 997/997 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - loss: 0.0013
# Epoch 3/4
# 997/997 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - loss: 9.7583e-04
# Epoch 4/4
# 997/997 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - loss: 9.5355e-04
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_8 (GRU)                     │ (None, 20, 50)         │         8,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 20, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_9 (GRU)                     │ (None, 20, 50)         │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_10 (GRU)                    │ (None, 20, 50)         │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_11 (GRU)                    │ (None, 50)             │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │           153 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 108,908 (425.43 KB)
#  Trainable params: 54,453 (212.71 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 54,455 (212.72 KB)

# %%
plt.plot(rnn[1], c='r', ls='--', label=ticker)
#plt.plot(forest[0], label='forest')
plt.plot(rnn[0], label='RNN')
plt.plot(lstm[0], label='LSTM')
plt.plot(gru[0], label='GRU')
# plt.plot(lstm1[0], label='GRU1')
plt.plot(gru1[0], label='GRU1')
# plt.plot(rnnPSAR[0][:len(rnn[1])], label='RNN1')
# plt.plot(lstmPSAR[0][:len(rnn[1])], label='LSTM1')
plt.plot(gruPSAR[0][:len(rnn[1])], label='GRU2')
plt.legend(loc='best')

# %%
import numpy as np
# best = (np.array(lstm[0]) * 1.2 + np.array(gru[0]) + np.array(gru1[0]) + np.array(rnn[0]) * 0.8 + np.array(forest[0][:len(lstm[0])]).reshape(-1, 1)) / 6
# best = (best + np.array(forest[0]).reshape(-1, 1)) / 2
best = np.array(lstm[0]) + np.array(gru[0])  + np.array(rnn[0]) + np.array(gru1[0]) + gruPSAR[0].reshape((-1, 1))[:len(rnn[1])]
best = best / 5
plt.plot(rnn[1], label=ticker, ls='--', c='r')
plt.plot(best, label='forecast')
plt.legend(loc='best')

# %%
train = data['Adj Close'][:len(data) - len(rnn[1])]
x1 = np.arange(len(train))
x2 = np.arange(len(train), len(train) + len(rnn[1]))
plt.plot(x2,rnn[1], label=ticker, ls='--', c='r')
plt.plot(x2, best, label='forecast', c='b')
plt.plot(x1, train, label='train')
plt.plot(x2, gru1[0], label='GRU RSI', ls=':')
plt.plot(x2, gru[0], label='GRU BL', ls=':')
plt.plot(x2, lstm[0], label='LSTM BL', ls=':')
plt.plot(x2, rnn[0], label='RNN BL', ls=':')
plt.plot(x2, gruPSAR[0][:len(rnn[1])],label='GRU PSAR', ls=':')
plt.legend(loc='best')

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mape
def MDA(X, Y):
    if len(X) != len(Y):
        return None
    s = .0
    for i in range(1, len(X)):
        if np.sign(X[i] - X[i-1]) == np.sign(Y[i] - Y[i-1]):
            s += 1
        else:
            s -= 1
    return (1 - (s / len(X))) / 2
def metrics(res):
    benches = []
    days = [5, 10, 15, 20, 40, 252]
    for l in days:
        bench = {}
        bench['days'] = l
        bench['mse'] = round(mse(res[1][:l], res[0][:l]), 3)
        bench['mda'] = round(MDA(res[1][:l], res[0][:l]), 3)
        bench['mse x mda'] = round(bench['mse'] * bench['mda'], 3)
        
        benches.append(bench)
    return benches
def MDA(X, Y):
    if len(X) != len(Y):
        return None
    s = .0
    for i in range(1, len(X)):
        if np.sign(X[i] - X[i-1]) == np.sign(Y[i] - Y[i-1]):
            s += 1
        else:
            s -= 1
    return (1 - (s / len(X))) / 2
def metrics(res):
    benches = []
    days = [5, 10, 15, 20, 40, 252]
    for l in days:
        bench = {}
        bench['days'] = l
        bench['mse'] = round(mse(res[1][:l], res[0][:l]), 3)
        bench['mda'] = round(MDA(res[1][:l], res[0][:l]), 3)
        bench['mape'] = round(mape(res[1][:l], res[0][:l]), 3)
        
        benches.append(bench)

    return benches

# %%
metrics(forest)
# Out:
# [{'days': 5, 'mse': 1.032, 'mda': 0.5, 'mape': 0.873},
#  {'days': 10, 'mse': 1.758, 'mda': 0.45, 'mape': 1.207},
#  {'days': 15, 'mse': 2.29, 'mda': 0.367, 'mape': 1.415},
#  {'days': 20, 'mse': 2.858, 'mda': 0.375, 'mape': 1.593},
#  {'days': 40, 'mse': 9.88, 'mda': 0.412, 'mape': 2.716},
#  {'days': 252, 'mse': 142.689, 'mda': 0.482, 'mape': 11.161}]

# %%
metrics(rnn)
# Out:
# [{'days': 5, 'mse': 0.765, 'mda': 0.5, 'mape': 0.778},
#  {'days': 10, 'mse': 1.47, 'mda': 0.55, 'mape': 1.122},
#  {'days': 15, 'mse': 2.716, 'mda': 0.567, 'mape': 1.502},
#  {'days': 20, 'mse': 3.608, 'mda': 0.575, 'mape': 1.752},
#  {'days': 40, 'mse': 3.454, 'mda': 0.438, 'mape': 1.764},
#  {'days': 252, 'mse': 20.192, 'mda': 0.458, 'mape': 3.911}]

# %%
metrics(lstm)
# Out:
# [{'days': 5, 'mse': 0.556, 'mda': 0.5, 'mape': 0.652},
#  {'days': 10, 'mse': 1.074, 'mda': 0.55, 'mape': 0.952},
#  {'days': 15, 'mse': 2.14, 'mda': 0.567, 'mape': 1.314},
#  {'days': 20, 'mse': 3.145, 'mda': 0.575, 'mape': 1.605},
#  {'days': 40, 'mse': 17.692, 'mda': 0.438, 'mape': 3.332},
#  {'days': 252, 'mse': 167.613, 'mda': 0.506, 'mape': 11.258}]

# %%
metrics(gru)
# Out:
# [{'days': 5, 'mse': 0.126, 'mda': 0.5, 'mape': 0.317},
#  {'days': 10, 'mse': 0.188, 'mda': 0.55, 'mape': 0.404},
#  {'days': 15, 'mse': 0.443, 'mda': 0.567, 'mape': 0.585},
#  {'days': 20, 'mse': 0.557, 'mda': 0.575, 'mape': 0.674},
#  {'days': 40, 'mse': 0.362, 'mda': 0.438, 'mape': 0.493},
#  {'days': 252, 'mse': 65.229, 'mda': 0.458, 'mape': 6.255}]

# %%
metrics(gru1)
# Out:
# [{'days': 5, 'mse': 0.259, 'mda': 0.5, 'mape': 0.403},
#  {'days': 10, 'mse': 0.568, 'mda': 0.55, 'mape': 0.664},
#  {'days': 15, 'mse': 1.255, 'mda': 0.567, 'mape': 0.975},
#  {'days': 20, 'mse': 1.734, 'mda': 0.575, 'mape': 1.175},
#  {'days': 40, 'mse': 2.487, 'mda': 0.438, 'mape': 1.423},
#  {'days': 252, 'mse': 132.021, 'mda': 0.458, 'mape': 10.069}]

# %%
metrics(gruPSAR)
# Out:
# [{'days': 5, 'mse': 0.006, 'mda': 0.3, 'mape': 0.073},
#  {'days': 10, 'mse': 0.009, 'mda': 0.55, 'mape': 0.081},
#  {'days': 15, 'mse': 0.185, 'mda': 0.633, 'mape': 0.293},
#  {'days': 20, 'mse': 0.224, 'mda': 0.525, 'mape': 0.331},
#  {'days': 40, 'mse': 4.769, 'mda': 0.487, 'mape': 1.422},
#  {'days': 252, 'mse': 43.991, 'mda': 0.573, 'mape': 5.347}]

# %%
metrics((best, rnn[1]))
# Out:
# [{'days': 5, 'mse': 0.813, 'mda': 0.5, 'mape': 0.834},
#  {'days': 10, 'mse': 1.259, 'mda': 0.55, 'mape': 1.068},
#  {'days': 15, 'mse': 2.031, 'mda': 0.567, 'mape': 1.336},
#  {'days': 20, 'mse': 2.5, 'mda': 0.575, 'mape': 1.495},
#  {'days': 40, 'mse': 3.023, 'mda': 0.438, 'mape': 1.626},
#  {'days': 252, 'mse': 9.977, 'mda': 0.486, 'mape': 2.514}]

# %%
import pandas as pd
