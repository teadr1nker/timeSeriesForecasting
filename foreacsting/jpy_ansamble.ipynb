# %%
import yfinance as yf
from best_test import testBest
import matplotlib.pyplot as plt
from RNN_PSAR import testRNNPSAR
# Out:
# 2024-06-03 00:14:45.355757: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-03 00:14:45.357106: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-03 00:14:45.359524: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-03 00:14:45.388804: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-03 00:14:46.161187: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Seed: 30245
# Seed: 30245

# %%
ticker = 'jpy=x'
data = yf.download(ticker, '2012-01-01', '2022-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
plt.plot(data['Adj Close'])

# %%
res = testBest(data['Adj Close'].values, 20)
# Out:
# 2084
# (70, 1)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:32: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# (2014, 20, 3)
# Epoch 1/4
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0103
# Epoch 2/4
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0020
# Epoch 3/4
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0014
# Epoch 4/4
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0011
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 20, 50)         │         2,700 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 20, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, 20, 50)         │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_2 (SimpleRNN)        │ (None, 20, 25)         │         1,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_3 (SimpleRNN)        │ (None, 50)             │         3,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,004 (105.49 KB)
#  Trainable params: 13,501 (52.74 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 13,503 (52.75 KB)
# (70, 1)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# (2014, 20, 3)
# Epoch 1/6
# 2014/2014 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 1.8244e-04 - loss: 0.0082
# Epoch 2/6
# 2014/2014 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 1.8244e-04 - loss: 7.8273e-04
# Epoch 3/6
# 2014/2014 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 1.8244e-04 - loss: 5.9816e-04
# Epoch 4/6
# 2014/2014 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 1.8244e-04 - loss: 4.6273e-04
# Epoch 5/6
# 2014/2014 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 1.8244e-04 - loss: 4.1687e-04
# Epoch 6/6
# 2014/2014 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 1.8244e-04 - loss: 3.9615e-04
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 20, 50)         │        10,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 96,905 (378.54 KB)
#  Trainable params: 32,301 (126.18 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 64,604 (252.36 KB)
# (70, 1)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:32: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# (2014, 20, 3)
# Epoch 1/4
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0154
# Epoch 2/4
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0017
# Epoch 3/4
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0013
# Epoch 4/4
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0011
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 20, 50)         │         8,250 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 20, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 20, 50)         │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 20, 50)         │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 50)             │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 108,404 (423.46 KB)
#  Trainable params: 54,201 (211.72 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 54,203 (211.73 KB)
# (70, 1)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:32: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# (2014, 20, 2)
# Epoch 1/4
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0177
# Epoch 2/4
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0011
# Epoch 3/4
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 9.5203e-04
# Epoch 4/4
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 9.8897e-04
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_4 (GRU)                     │ (None, 20, 50)         │         8,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 20, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_5 (GRU)                     │ (None, 20, 50)         │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_6 (GRU)                     │ (None, 20, 50)         │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_7 (GRU)                     │ (None, 50)             │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 108,104 (422.29 KB)
#  Trainable params: 54,051 (211.14 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 54,053 (211.15 KB)

# %%
train ,forest, rnn, lstm, gru, gru1 = res

# %%
gruPSAR = testRNNPSAR(data[['Adj Close', 'Low', 'High']])
# Out:
# (20, 3)
# (2064, 20, 4) train
# (2064, 3) train fr
# Epoch 1/4
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:32: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# 1032/1032 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0154
# Epoch 2/4
# 1032/1032 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0013
# Epoch 3/4
# 1032/1032 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0010
# Epoch 4/4
# 1032/1032 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 9.4715e-04
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_8 (GRU)                     │ (None, 20, 50)         │         8,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 20, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_9 (GRU)                     │ (None, 20, 50)         │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_10 (GRU)                    │ (None, 20, 50)         │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_11 (GRU)                    │ (None, 50)             │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │           153 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 108,908 (425.43 KB)
#  Trainable params: 54,453 (212.71 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 54,455 (212.72 KB)

# %%
plt.plot(rnn[1], c='r', ls='--', label=ticker)
#plt.plot(forest[0], label='forest')
plt.plot(rnn[0], label='RNN')
plt.plot(lstm[0], label='LSTM')
plt.plot(gru[0], label='GRU')
# plt.plot(lstm1[0], label='GRU1')
plt.plot(gru1[0], label='GRU1')
# plt.plot(rnnPSAR[0][:len(rnn[1])], label='RNN1')
# plt.plot(lstmPSAR[0][:len(rnn[1])], label='LSTM1')
plt.plot(gruPSAR[0][:len(rnn[1])], label='GRU2')
plt.legend(loc='best')

# %%
import numpy as np
# best = (np.array(lstm[0]) * 1.2 + np.array(gru[0]) + np.array(gru1[0]) + np.array(rnn[0]) * 0.8 + np.array(forest[0][:len(lstm[0])]).reshape(-1, 1)) / 6
# best = (best + np.array(forest[0]).reshape(-1, 1)) / 2
best = np.array(lstm[0]) + np.array(gru[0])  + np.array(rnn[0]) + np.array(gru1[0]) + gruPSAR[0].reshape((-1, 1))[:len(rnn[1])]
best = best / 5
plt.plot(rnn[1], label=ticker, ls='--', c='r')
plt.plot(best, label='forecast')
plt.legend(loc='best')

# %%
train = data['Adj Close'][:len(data) - len(rnn[1])]
x1 = np.arange(len(train))
x2 = np.arange(len(train), len(train) + len(rnn[1]))
plt.plot(x2,rnn[1], label=ticker, ls='--', c='r')
plt.plot(x2, best, label='forecast', c='b')
plt.plot(x1, train, label='train')
plt.plot(x2, gru1[0], label='GRU RSI', ls=':')
plt.plot(x2, gru[0], label='GRU BL', ls=':')
plt.plot(x2, lstm[0], label='LSTM BL', ls=':')
plt.plot(x2, rnn[0], label='RNN BL', ls=':')
plt.plot(x2, gruPSAR[0][:len(rnn[1])],label='GRU PSAR', ls=':')
plt.legend(loc='best')

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mape
def MDA(X, Y):
    if len(X) != len(Y):
        return None
    s = .0
    for i in range(1, len(X)):
        if np.sign(X[i] - X[i-1]) == np.sign(Y[i] - Y[i-1]):
            s += 1
        else:
            s -= 1
    return (1 - (s / len(X))) / 2
def metrics(res):
    benches = []
    days = [5, 10, 15, 20, 40, 252]
    for l in days:
        bench = {}
        bench['days'] = l
        bench['mse'] = round(mse(res[1][:l], res[0][:l]), 3)
        bench['mda'] = round(MDA(res[1][:l], res[0][:l]), 3)
        bench['mse x mda'] = round(bench['mse'] * bench['mda'], 3)
        
        benches.append(bench)
    return benches
def MDA(X, Y):
    if len(X) != len(Y):
        return None
    s = .0
    for i in range(1, len(X)):
        if np.sign(X[i] - X[i-1]) == np.sign(Y[i] - Y[i-1]):
            s += 1
        else:
            s -= 1
    return (1 - (s / len(X))) / 2
def metrics(res):
    benches = []
    days = [5, 10, 15, 20, 40, 252]
    for l in days:
        bench = {}
        bench['days'] = l
        bench['mse'] = round(mse(res[1][:l], res[0][:l]), 6)
        bench['mda'] = round(MDA(res[1][:l], res[0][:l]), 6)
        bench['mape'] = round(mape(res[1][:l], res[0][:l]), 3)
        
        benches.append(bench)

    return benches

# %%
metrics(forest)
# Out:
# [{'days': 5, 'mse': 0.085186, 'mda': 0.3, 'mape': 0.191},
#  {'days': 10, 'mse': 0.235749, 'mda': 0.45, 'mape': 0.352},
#  {'days': 15, 'mse': 0.46929, 'mda': 0.366667, 'mape': 0.524},
#  {'days': 20, 'mse': 0.769429, 'mda': 0.475, 'mape': 0.703},
#  {'days': 40, 'mse': 0.631863, 'mda': 0.4375, 'mape': 0.662},
#  {'days': 252, 'mse': 1196.039129, 'mda': 0.505952, 'mape': 26.498}]

# %%
metrics(rnn)
# Out:
# [{'days': 5, 'mse': 0.876348, 'mda': 0.9, 'mape': 0.713},
#  {'days': 10, 'mse': 1.345656, 'mda': 0.65, 'mape': 1.025},
#  {'days': 15, 'mse': 2.205735, 'mda': 0.7, 'mape': 1.329},
#  {'days': 20, 'mse': 3.577031, 'mda': 0.725, 'mape': 1.686},
#  {'days': 40, 'mse': 4.590994, 'mda': 0.5875, 'mape': 2.005},
#  {'days': 252, 'mse': 24.231539, 'mda': 0.501984, 'mape': 4.528}]

# %%
metrics(lstm)
# Out:
# [{'days': 5, 'mse': 10.531232, 'mda': 0.9, 'mape': 2.823},
#  {'days': 10, 'mse': 26.035238, 'mda': 0.65, 'mape': 4.606},
#  {'days': 15, 'mse': 47.667747, 'mda': 0.7, 'mape': 6.228},
#  {'days': 20, 'mse': 76.256495, 'mda': 0.725, 'mape': 7.845},
#  {'days': 40, 'mse': 192.732846, 'mda': 0.5875, 'mape': 12.671},
#  {'days': 252, 'mse': 591.583465, 'mda': 0.541667, 'mape': 23.681}]

# %%
metrics(gru)
# Out:
# [{'days': 5, 'mse': 1.620606, 'mda': 0.1, 'mape': 1.185},
#  {'days': 10, 'mse': 2.453721, 'mda': 0.35, 'mape': 1.484},
#  {'days': 15, 'mse': 3.775616, 'mda': 0.3, 'mape': 1.833},
#  {'days': 20, 'mse': 4.962658, 'mda': 0.275, 'mape': 2.101},
#  {'days': 40, 'mse': 20.867478, 'mda': 0.4125, 'mape': 3.992},
#  {'days': 252, 'mse': 239.250116, 'mda': 0.498016, 'mape': 14.264}]

# %%
metrics(gru1)
# Out:
# [{'days': 5, 'mse': 1.457114, 'mda': 0.1, 'mape': 1.102},
#  {'days': 10, 'mse': 2.134023, 'mda': 0.35, 'mape': 1.373},
#  {'days': 15, 'mse': 3.378, 'mda': 0.3, 'mape': 1.722},
#  {'days': 20, 'mse': 4.63443, 'mda': 0.275, 'mape': 2.012},
#  {'days': 40, 'mse': 23.363339, 'mda': 0.4125, 'mape': 4.135},
#  {'days': 252, 'mse': 594.37006, 'mda': 0.763889, 'mape': 22.44}]

# %%
metrics(gruPSAR)
# Out:
# [{'days': 5, 'mse': 4.018854, 'mda': 0.3, 'mape': 1.982},
#  {'days': 10, 'mse': 3.742531, 'mda': 0.25, 'mape': 1.908},
#  {'days': 15, 'mse': 5.149412, 'mda': 0.233333, 'mape': 2.209},
#  {'days': 20, 'mse': 5.453411, 'mda': 0.325, 'mape': 2.257},
#  {'days': 40, 'mse': 38.808513, 'mda': 0.3875, 'mape': 5.199},
#  {'days': 252, 'mse': 256.050343, 'mda': 0.501984, 'mape': 15.071}]

# %%
metrics((best, rnn[1]))
# Out:
# [{'days': 5, 'mse': 1.242934, 'mda': 0.9, 'mape': 0.874},
#  {'days': 10, 'mse': 1.986307, 'mda': 0.65, 'mape': 1.258},
#  {'days': 15, 'mse': 3.22041, 'mda': 0.7, 'mape': 1.619},
#  {'days': 20, 'mse': 5.159979, 'mda': 0.725, 'mape': 2.038},
#  {'days': 40, 'mse': 7.734645, 'mda': 0.5875, 'mape': 2.612},
#  {'days': 252, 'mse': 4.708666, 'mda': 0.525794, 'mape': 1.919}]

# %%
import pandas as pd
