# %%
import yfinance as yf
from best_test import testBest
import matplotlib.pyplot as plt
from RNN_PSAR import testRNNPSAR
# Out:
# 2024-06-02 23:56:05.989077: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-02 23:56:05.989260: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-02 23:56:05.991648: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-02 23:56:06.020626: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
ticker = 'eurusd=x'
data = yf.download(ticker, '2012-01-01', '2022-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
plt.plot(data['Adj Close'])

# %%
res = testBest(data['Adj Close'].values, 20)
# Out:
# 2084
# (70, 1)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:32: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# (2014, 20, 3)
# Epoch 1/4
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.0107
# Epoch 2/4
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0024
# Epoch 3/4
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0017
# Epoch 4/4
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0016
# Model: "sequential"
# ...

# %%
train ,forest, rnn, lstm, gru, gru1 = res

# %%
gruPSAR = testRNNPSAR(data[['Adj Close', 'Low', 'High']])
# Out:
# (20, 3)
# (2064, 20, 4) train
# (2064, 3) train fr
# Epoch 1/4
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /home/tea/.var/app/org.jupyter.JupyterLab/config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:32: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# 1032/1032 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.0138
# Epoch 2/4
# 1032/1032 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0014
# Epoch 3/4
# 1032/1032 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0012
# Epoch 4/4
# 1032/1032 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0011
# Model: "sequential_4"
# ...

# %%
plt.plot(rnn[1], c='r', ls='--', label=ticker)
#plt.plot(forest[0], label='forest')
plt.plot(rnn[0], label='RNN')
plt.plot(lstm[0], label='LSTM')
plt.plot(gru[0], label='GRU')
# plt.plot(lstm1[0], label='GRU1')
plt.plot(gru1[0], label='GRU1')
# plt.plot(rnnPSAR[0][:len(rnn[1])], label='RNN1')
# plt.plot(lstmPSAR[0][:len(rnn[1])], label='LSTM1')
plt.plot(gruPSAR[0][:len(rnn[1])], label='GRU2')
plt.legend(loc='best')

# %%
import numpy as np
# best = (np.array(lstm[0]) * 1.2 + np.array(gru[0]) + np.array(gru1[0]) + np.array(rnn[0]) * 0.8 + np.array(forest[0][:len(lstm[0])]).reshape(-1, 1)) / 6
# best = (best + np.array(forest[0]).reshape(-1, 1)) / 2
best = np.array(lstm[0]) + np.array(gru[0])  + np.array(rnn[0]) + np.array(gru1[0]) + gruPSAR[0].reshape((-1, 1))[:len(rnn[1])]
best = best / 5
plt.plot(rnn[1], label=ticker, ls='--', c='r')
plt.plot(best, label='forecast')
plt.legend(loc='best')

# %%
train = data['Adj Close'][:len(data) - len(rnn[1])]
x1 = np.arange(len(train))
x2 = np.arange(len(train), len(train) + len(rnn[1]))
plt.plot(x2,rnn[1], label=ticker, ls='--', c='r')
plt.plot(x2, best, label='forecast', c='b')
plt.plot(x1, train, label='train')
plt.plot(x2, gru1[0], label='GRU RSI', ls=':')
plt.plot(x2, gru[0], label='GRU BL', ls=':')
plt.plot(x2, lstm[0], label='LSTM BL', ls=':')
plt.plot(x2, rnn[0], label='RNN BL', ls=':')
plt.plot(x2, gruPSAR[0][:len(rnn[1])],label='GRU PSAR', ls=':')
plt.legend(loc='best')

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mape
def MDA(X, Y):
    if len(X) != len(Y):
        return None
    s = .0
    for i in range(1, len(X)):
        if np.sign(X[i] - X[i-1]) == np.sign(Y[i] - Y[i-1]):
            s += 1
        else:
            s -= 1
    return (1 - (s / len(X))) / 2
def metrics(res):
    benches = []
    days = [5, 10, 15, 20, 40, 252]
    for l in days:
        bench = {}
        bench['days'] = l
        bench['mse'] = round(mse(res[1][:l], res[0][:l]), 3)
        bench['mda'] = round(MDA(res[1][:l], res[0][:l]), 3)
        bench['mse x mda'] = round(bench['mse'] * bench['mda'], 3)
        
        benches.append(bench)
    return benches
def MDA(X, Y):
    if len(X) != len(Y):
        return None
    s = .0
    for i in range(1, len(X)):
        if np.sign(X[i] - X[i-1]) == np.sign(Y[i] - Y[i-1]):
            s += 1
        else:
            s -= 1
    return (1 - (s / len(X))) / 2
def metrics(res):
    benches = []
    days = [5, 10, 15, 20, 40, 252]
    for l in days:
        bench = {}
        bench['days'] = l
        bench['mse'] = round(mse(res[1][:l], res[0][:l]), 6)
        bench['mda'] = round(MDA(res[1][:l], res[0][:l]), 6)
        bench['mape'] = round(mape(res[1][:l], res[0][:l]), 3)
        
        benches.append(bench)

    return benches

# %%
metrics(forest)
# Out:
# [{'days': 5, 'mse': 2.5e-05, 'mda': 0.5, 'mape': 0.004},
#  {'days': 10, 'mse': 0.000388, 'mda': 0.45, 'mape': 0.015},
#  {'days': 15, 'mse': 0.000814, 'mda': 0.366667, 'mape': 0.024},
#  {'days': 20, 'mse': 0.000909, 'mda': 0.425, 'mape': 0.026},
#  {'days': 40, 'mse': 0.000637, 'mda': 0.4375, 'mape': 0.022},
#  {'days': 252, 'mse': 0.002029, 'mda': 0.53373, 'mape': 0.034}]

# %%
metrics(rnn)
# Out:
# [{'days': 5, 'mse': 7.4e-05, 'mda': 0.5, 'mape': 0.008},
#  {'days': 10, 'mse': 4.9e-05, 'mda': 0.45, 'mape': 0.006},
#  {'days': 15, 'mse': 5e-05, 'mda': 0.433333, 'mape': 0.006},
#  {'days': 20, 'mse': 4.8e-05, 'mda': 0.575, 'mape': 0.006},
#  {'days': 40, 'mse': 0.000115, 'mda': 0.4625, 'mape': 0.008},
#  {'days': 252, 'mse': 0.005348, 'mda': 0.470238, 'mape': 0.065}]

# %%
metrics(lstm)
# Out:
# [{'days': 5, 'mse': 0.000243, 'mda': 0.5, 'mape': 0.012},
#  {'days': 10, 'mse': 0.001855, 'mda': 0.65, 'mape': 0.035},
#  {'days': 15, 'mse': 0.004815, 'mda': 0.5, 'mape': 0.058},
#  {'days': 20, 'mse': 0.00909, 'mda': 0.525, 'mape': 0.08},
#  {'days': 40, 'mse': 0.031511, 'mda': 0.5375, 'mape': 0.156},
#  {'days': 252, 'mse': 0.081447, 'mda': 0.494048, 'mape': 0.275}]

# %%
metrics(gru)
# Out:
# [{'days': 5, 'mse': 0.000436, 'mda': 0.5, 'mape': 0.02},
#  {'days': 10, 'mse': 0.000523, 'mda': 0.35, 'mape': 0.023},
#  {'days': 15, 'mse': 0.000784, 'mda': 0.5, 'mape': 0.027},
#  {'days': 20, 'mse': 0.001218, 'mda': 0.625, 'mape': 0.033},
#  {'days': 40, 'mse': 0.002292, 'mda': 0.8125, 'mape': 0.045},
#  {'days': 252, 'mse': 0.018682, 'mda': 0.96627, 'mape': 0.129}]

# %%
metrics(gru1)
# Out:
# [{'days': 5, 'mse': 0.00039, 'mda': 0.5, 'mape': 0.019},
#  {'days': 10, 'mse': 0.00045, 'mda': 0.35, 'mape': 0.021},
#  {'days': 15, 'mse': 0.000654, 'mda': 0.5, 'mape': 0.025},
#  {'days': 20, 'mse': 0.001083, 'mda': 0.525, 'mape': 0.031},
#  {'days': 40, 'mse': 0.002225, 'mda': 0.7625, 'mape': 0.044},
#  {'days': 252, 'mse': 0.018672, 'mda': 0.958333, 'mape': 0.129}]

# %%
metrics(gruPSAR)
# Out:
# [{'days': 5, 'mse': 4.7e-05, 'mda': 0.3, 'mape': 0.006},
#  {'days': 10, 'mse': 2.7e-05, 'mda': 0.25, 'mape': 0.004},
#  {'days': 15, 'mse': 3.5e-05, 'mda': 0.233333, 'mape': 0.005},
#  {'days': 20, 'mse': 3.2e-05, 'mda': 0.375, 'mape': 0.005},
#  {'days': 40, 'mse': 0.000687, 'mda': 0.4875, 'mape': 0.018},
#  {'days': 252, 'mse': 0.013427, 'mda': 0.823413, 'mape': 0.1}]

# %%
metrics((best, rnn[1]))
# Out:
# [{'days': 5, 'mse': 4.5e-05, 'mda': 0.7, 'mape': 0.006},
#  {'days': 10, 'mse': 3.7e-05, 'mda': 0.75, 'mape': 0.005},
#  {'days': 15, 'mse': 5.9e-05, 'mda': 0.566667, 'mape': 0.007},
#  {'days': 20, 'mse': 8.2e-05, 'mda': 0.575, 'mape': 0.007},
#  {'days': 40, 'mse': 0.000271, 'mda': 0.5875, 'mape': 0.013},
#  {'days': 252, 'mse': 0.001784, 'mda': 0.494048, 'mape': 0.037}]

# %%
import pandas as pd
